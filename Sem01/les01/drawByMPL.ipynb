# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

# %%
# Simple draw

x = np.arange(10)
y = np.random.randint(1, 10, size = 10)
z = np.random.randint(1, 10, size = 10)

plt.figure(figsize=(10, 7))

plt.plot(x, y, label = "y from x")
plt.plot(x, z, label = "z from x")

plt.title("Зависимость x от некоторых даннных")

plt.legend()

plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot(x, y)

# %% [markdown]
# <h4>With DataFrame as source</h4>

# %%
# Загрузка датасета
iris = load_iris()

# Преобразование в DataFrame
iris_data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_data['target'] = iris.target

# Вывод первых строк датасета
print(iris_data.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
